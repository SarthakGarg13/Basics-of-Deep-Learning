# %% [markdown]
# <a href="https://colab.research.google.com/github/SarthakGarg13/Basics-of-Deep-Learning/blob/master/Inception_tf_2_2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.layers.core import Layer
import keras.backend as K
import tensorflow as tf
from keras.datasets import cifar10
print(tf.__version__)
# Out:
# Using TensorFlow backend.
# 2.2.0

# %%
from keras.models import Model
from keras.layers import Conv2D, MaxPool2D,  \
    Dropout, Dense, Input, concatenate,      \
    GlobalAveragePooling2D, AveragePooling2D,\
    Flatten

import cv2 
import numpy as np 
from keras.datasets import cifar10 
from keras import backend as K 
from keras.utils import np_utils

import math 
from keras.optimizers import SGD 
from keras.callbacks import LearningRateScheduler

# %%
# !nvidia-smi
# Out:
# Mon May 25 20:32:49 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
num_classes = 10

def load_cifar10_data(img_rows, img_cols):

    # Load cifar10 training and validation sets

    (X_train, Y_train), (X_valid, Y_valid) = cifar10.load_data()
    
    # Transform targets to keras compatible format
    Y_train = np_utils.to_categorical(Y_train, num_classes)
    Y_valid = np_utils.to_categorical(Y_valid, num_classes)
    
    X_train = X_train.astype('float32')
    X_valid = X_valid.astype('float32')

    # preprocess data
    X_train = X_train / 255.0
    X_valid = X_valid / 255.0

    return X_train, Y_train, X_valid, Y_valid

# %%
X_train, y_train, X_test, y_test = load_cifar10_data(224, 224)

# %%
def inception_module(x,
                     filters_1x1,
                     filters_3x3_reduce,
                     filters_3x3,
                     filters_5x5_reduce,
                     filters_5x5,
                     filters_pool_proj,
                     name=None):
    
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    
    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_5x5)

    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(pool_proj)

    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=3, name=name)
    
    return output

# %% [markdown]
# ## Glorout Initialisation
#
# To keep the mean and std between 0 and 1 respectively.
# Preventing exploding and vanishing gradients.

# %%
kernel_init = keras.initializers.glorot_uniform()
bias_init = keras.initializers.Constant(value=0.2)

# %%
input_layer = Input(shape=(32, 32, 3))

x = Conv2D(64, (7, 7), padding='same', strides=(2, 2), activation='relu', name='conv_1_7x7/2', kernel_initializer=kernel_init, bias_initializer=bias_init)(input_layer)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_1_3x3/2')(x)
x = Conv2D(64, (1, 1), padding='same', strides=(1, 1), activation='relu', name='conv_2a_3x3/1')(x)
x = Conv2D(192, (3, 3), padding='same', strides=(1, 1), activation='relu', name='conv_2b_3x3/1')(x)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_2_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=64,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_3a')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=192,
                     filters_5x5_reduce=32,
                     filters_5x5=96,
                     filters_pool_proj=64,
                     name='inception_3b')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_3_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=192,
                     filters_3x3_reduce=96,
                     filters_3x3=208,
                     filters_5x5_reduce=16,
                     filters_5x5=48,
                     filters_pool_proj=64,
                     name='inception_4a')


x1 = AveragePooling2D((2, 2), strides=1)(x)
x1 = Conv2D(128, (1, 1), padding='same', activation='relu')(x1)
x1 = Flatten()(x1)
x1 = Dense(1024, activation='relu')(x1)
x1 = Dropout(0.7)(x1)
x1 = Dense(10, activation='softmax', name='auxilliary_output_1')(x1)

x = inception_module(x,
                     filters_1x1=160,
                     filters_3x3_reduce=112,
                     filters_3x3=224,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4b')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=256,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4c')

x = inception_module(x,
                     filters_1x1=112,
                     filters_3x3_reduce=144,
                     filters_3x3=288,
                     filters_5x5_reduce=32,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4d')


x2 = AveragePooling2D((2, 2), strides=1)(x)
x2 = Conv2D(128, (1, 1), padding='same', activation='relu')(x2)
x2 = Flatten()(x2)
x2 = Dense(1024, activation='relu')(x2)
x2 = Dropout(0.7)(x2)
x2 = Dense(10, activation='softmax', name='auxilliary_output_2')(x2)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_4e')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_4_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5a')

x = inception_module(x,
                     filters_1x1=384,
                     filters_3x3_reduce=192,
                     filters_3x3=384,
                     filters_5x5_reduce=48,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5b')

x = GlobalAveragePooling2D(name='avg_pool_5_3x3/1')(x)

x = Dropout(0.4)(x)

x = Dense(10, activation='softmax', name='output')(x)
model = Model(input_layer, [x, x1, x2], name='inception_v1')
#Let us summarize our model to check if our work so far has gone well.
model.summary()
# Out:
# Model: "inception_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv_1_7x7/2 (Conv2D)           (None, 16, 16, 64)   9472        input_8[0][0]
# __________________________________________________________________________________________________
# max_pool_1_3x3/2 (MaxPooling2D) (None, 8, 8, 64)     0           conv_1_7x7/2[0][0]
# __________________________________________________________________________________________________
# conv_2a_3x3/1 (Conv2D)          (None, 8, 8, 64)     4160        max_pool_1_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv_2b_3x3/1 (Conv2D)          (None, 8, 8, 192)    110784      conv_2a_3x3/1[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 4, 4, 192)    0           conv_2b_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 4, 4, 96)     18528       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 4, 4, 16)     3088        max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_43 (MaxPooling2D) (None, 4, 4, 192)    0           max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 4, 4, 64)     12352       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 4, 4, 128)    110720      conv2d_261[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 4, 4, 32)     12832       conv2d_263[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 4, 4, 32)     6176        max_pooling2d_43[0][0]
# __________________________________________________________________________________________________
# inception_3a (Concatenate)      (None, 4, 4, 256)    0           conv2d_260[0][0]
#                                                                  conv2d_262[0][0]
#                                                                  conv2d_264[0][0]
#                                                                  conv2d_265[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 4, 4, 128)    32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 4, 4, 32)     8224        inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_44 (MaxPooling2D) (None, 4, 4, 256)    0           inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 4, 4, 128)    32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 4, 4, 192)    221376      conv2d_267[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 4, 4, 96)     76896       conv2d_269[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 4, 4, 64)     16448       max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# inception_3b (Concatenate)      (None, 4, 4, 480)    0           conv2d_266[0][0]
#                                                                  conv2d_268[0][0]
#                                                                  conv2d_270[0][0]
#                                                                  conv2d_271[0][0]
# __________________________________________________________________________________________________
# max_pool_3_3x3/2 (MaxPooling2D) (None, 2, 2, 480)    0           inception_3b[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 2, 2, 96)     46176       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 2, 2, 16)     7696        max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_45 (MaxPooling2D) (None, 2, 2, 480)    0           max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 2, 2, 192)    92352       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 2, 2, 208)    179920      conv2d_273[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 2, 2, 48)     19248       conv2d_275[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 2, 2, 64)     30784       max_pooling2d_45[0][0]
# __________________________________________________________________________________________________
# inception_4a (Concatenate)      (None, 2, 2, 512)    0           conv2d_272[0][0]
#                                                                  conv2d_274[0][0]
#                                                                  conv2d_276[0][0]
#                                                                  conv2d_277[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 2, 2, 112)    57456       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_282 (Conv2D)             (None, 2, 2, 24)     12312       inception_4a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_46 (MaxPooling2D) (None, 2, 2, 512)    0           inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 2, 2, 160)    82080       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 2, 2, 224)    226016      conv2d_280[0][0]
# __________________________________________________________________________________________________
# conv2d_283 (Conv2D)             (None, 2, 2, 64)     38464       conv2d_282[0][0]
# __________________________________________________________________________________________________
# conv2d_284 (Conv2D)             (None, 2, 2, 64)     32832       max_pooling2d_46[0][0]
# __________________________________________________________________________________________________
# inception_4b (Concatenate)      (None, 2, 2, 512)    0           conv2d_279[0][0]
#                                                                  conv2d_281[0][0]
#                                                                  conv2d_283[0][0]
#                                                                  conv2d_284[0][0]
# __________________________________________________________________________________________________
# conv2d_286 (Conv2D)             (None, 2, 2, 128)    65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_288 (Conv2D)             (None, 2, 2, 24)     12312       inception_4b[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_47 (MaxPooling2D) (None, 2, 2, 512)    0           inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_285 (Conv2D)             (None, 2, 2, 128)    65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_287 (Conv2D)             (None, 2, 2, 256)    295168      conv2d_286[0][0]
# __________________________________________________________________________________________________
# conv2d_289 (Conv2D)             (None, 2, 2, 64)     38464       conv2d_288[0][0]
# __________________________________________________________________________________________________
# conv2d_290 (Conv2D)             (None, 2, 2, 64)     32832       max_pooling2d_47[0][0]
# __________________________________________________________________________________________________
# inception_4c (Concatenate)      (None, 2, 2, 512)    0           conv2d_285[0][0]
#                                                                  conv2d_287[0][0]
#                                                                  conv2d_289[0][0]
#                                                                  conv2d_290[0][0]
# __________________________________________________________________________________________________
# conv2d_292 (Conv2D)             (None, 2, 2, 144)    73872       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_294 (Conv2D)             (None, 2, 2, 32)     16416       inception_4c[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_48 (MaxPooling2D) (None, 2, 2, 512)    0           inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_291 (Conv2D)             (None, 2, 2, 112)    57456       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_293 (Conv2D)             (None, 2, 2, 288)    373536      conv2d_292[0][0]
# __________________________________________________________________________________________________
# conv2d_295 (Conv2D)             (None, 2, 2, 64)     51264       conv2d_294[0][0]
# __________________________________________________________________________________________________
# conv2d_296 (Conv2D)             (None, 2, 2, 64)     32832       max_pooling2d_48[0][0]
# __________________________________________________________________________________________________
# inception_4d (Concatenate)      (None, 2, 2, 528)    0           conv2d_291[0][0]
#                                                                  conv2d_293[0][0]
#                                                                  conv2d_295[0][0]
#                                                                  conv2d_296[0][0]
# __________________________________________________________________________________________________
# conv2d_299 (Conv2D)             (None, 2, 2, 160)    84640       inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_301 (Conv2D)             (None, 2, 2, 32)     16928       inception_4d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_49 (MaxPooling2D) (None, 2, 2, 528)    0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_298 (Conv2D)             (None, 2, 2, 256)    135424      inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_300 (Conv2D)             (None, 2, 2, 320)    461120      conv2d_299[0][0]
# __________________________________________________________________________________________________
# conv2d_302 (Conv2D)             (None, 2, 2, 128)    102528      conv2d_301[0][0]
# __________________________________________________________________________________________________
# conv2d_303 (Conv2D)             (None, 2, 2, 128)    67712       max_pooling2d_49[0][0]
# __________________________________________________________________________________________________
# inception_4e (Concatenate)      (None, 2, 2, 832)    0           conv2d_298[0][0]
#                                                                  conv2d_300[0][0]
#                                                                  conv2d_302[0][0]
#                                                                  conv2d_303[0][0]
# __________________________________________________________________________________________________
# max_pool_4_3x3/2 (MaxPooling2D) (None, 1, 1, 832)    0           inception_4e[0][0]
# __________________________________________________________________________________________________
# conv2d_305 (Conv2D)             (None, 1, 1, 160)    133280      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_307 (Conv2D)             (None, 1, 1, 32)     26656       max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_50 (MaxPooling2D) (None, 1, 1, 832)    0           max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_304 (Conv2D)             (None, 1, 1, 256)    213248      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_306 (Conv2D)             (None, 1, 1, 320)    461120      conv2d_305[0][0]
# __________________________________________________________________________________________________
# conv2d_308 (Conv2D)             (None, 1, 1, 128)    102528      conv2d_307[0][0]
# __________________________________________________________________________________________________
# conv2d_309 (Conv2D)             (None, 1, 1, 128)    106624      max_pooling2d_50[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 1, 1, 832)    0           conv2d_304[0][0]
#                                                                  conv2d_306[0][0]
#                                                                  conv2d_308[0][0]
#                                                                  conv2d_309[0][0]
# __________________________________________________________________________________________________
# conv2d_311 (Conv2D)             (None, 1, 1, 192)    159936      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_313 (Conv2D)             (None, 1, 1, 48)     39984       inception_5a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_51 (MaxPooling2D) (None, 1, 1, 832)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, 1, 1, 512)    0           inception_4a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, 1, 1, 528)    0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_310 (Conv2D)             (None, 1, 1, 384)    319872      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_312 (Conv2D)             (None, 1, 1, 384)    663936      conv2d_311[0][0]
# __________________________________________________________________________________________________
# conv2d_314 (Conv2D)             (None, 1, 1, 128)    153728      conv2d_313[0][0]
# __________________________________________________________________________________________________
# conv2d_315 (Conv2D)             (None, 1, 1, 128)    106624      max_pooling2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 1, 1, 128)    65664       average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_297 (Conv2D)             (None, 1, 1, 128)    67712       average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# inception_5b (Concatenate)      (None, 1, 1, 1024)   0           conv2d_310[0][0]
#                                                                  conv2d_312[0][0]
#                                                                  conv2d_314[0][0]
#                                                                  conv2d_315[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 128)          0           conv2d_278[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 128)          0           conv2d_297[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_3x3/1 (GlobalAverage (None, 1024)         0           inception_5b[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1024)         132096      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1024)         132096      flatten_9[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 1024)         0           avg_pool_5_3x3/1[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 1024)         0           dense_8[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 1024)         0           dense_9[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 10)           10250       dropout_13[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_1 (Dense)     (None, 10)           10250       dropout_11[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_2 (Dense)     (None, 10)           10250       dropout_12[0][0]
# ==================================================================================================
# Total params: 6,401,870
# Trainable params: 6,401,870
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 25
initial_lrate = 0.01

def decay(epoch, steps=100):
    initial_lrate = 0.01
    drop = 0.96
    epochs_drop = 8
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

sgd = SGD(lr=initial_lrate, momentum=0.9, nesterov=False)

lr_sc = LearningRateScheduler(decay, verbose=1)

model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'], loss_weights=[1, 0.3, 0.3], optimizer=sgd, metrics=['accuracy'])

# %%
history = model.fit(X_train, [y_train, y_train, y_train], validation_data=(X_test, [y_test, y_test, y_test]), epochs=epochs, batch_size=256, callbacks=[lr_sc])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.01.
# 50000/50000 [==============================] - 20s 404us/step - loss: 3.4000 - output_loss: 2.1005 - auxilliary_output_1_loss: 2.1843 - auxilliary_output_2_loss: 2.1426 - output_accuracy: 0.2044 - auxilliary_output_1_accuracy: 0.1842 - auxilliary_output_2_accuracy: 0.1780 - val_loss: 4.1761 - val_output_loss: 2.7896 - val_auxilliary_output_1_loss: 2.2927 - val_auxilliary_output_2_loss: 2.3545 - val_output_accuracy: 0.1000 - val_auxilliary_output_1_accuracy: 0.1235 - val_auxilliary_output_2_accuracy: 0.1000
# Epoch 2/25
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.01.
# 50000/50000 [==============================] - 11s 219us/step - loss: 2.7320 - output_loss: 1.6879 - auxilliary_output_1_loss: 1.7471 - auxilliary_output_2_loss: 1.7296 - output_accuracy: 0.3664 - auxilliary_output_1_accuracy: 0.3470 - auxilliary_output_2_accuracy: 0.3512 - val_loss: 4.9193 - val_output_loss: 3.4378 - val_auxilliary_output_1_loss: 2.3223 - val_auxilliary_output_2_loss: 2.6607 - val_output_accuracy: 0.1000 - val_auxilliary_output_1_accuracy: 0.1000 - val_auxilliary_output_2_accuracy: 0.1000
# Epoch 3/25
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.01.
# 50000/50000 [==============================] - 11s 219us/step - loss: 2.4445 - output_loss: 1.5094 - auxilliary_output_1_loss: 1.5688 - auxilliary_output_2_loss: 1.5440 - output_accuracy: 0.4458 - auxilliary_output_1_accuracy: 0.4265 - auxilliary_output_2_accuracy: 0.4356 - val_loss: 5.5638 - val_output_loss: 3.9992 - val_auxilliary_output_1_loss: 2.3377 - val_auxilliary_output_2_loss: 2.9439 - val_output_accuracy: 0.0998 - val_auxilliary_output_1_accuracy: 0.1000 - val_auxilliary_output_2_accuracy: 0.1020
# Epoch 4/25
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.01.
# 50000/50000 [==============================] - 11s 219us/step - loss: 2.2551 - output_loss: 1.3955 - auxilliary_output_1_loss: 1.4440 - auxilliary_output_2_loss: 1.4248 - output_accuracy: 0.4940 - auxilliary_output_1_accuracy: 0.4790 - auxilliary_output_2_accuracy: 0.4846 - val_loss: 5.7655 - val_output_loss: 4.1504 - val_auxilliary_output_1_loss: 2.3443 - val_auxilliary_output_2_loss: 3.1094 - val_output_accuracy: 0.1033 - val_auxilliary_output_1_accuracy: 0.1126 - val_auxilliary_output_2_accuracy: 0.1181
# Epoch 5/25
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.01.
# 50000/50000 [==============================] - 11s 218us/step - loss: 2.1001 - output_loss: 1.2995 - auxilliary_output_1_loss: 1.3443 - auxilliary_output_2_loss: 1.3227 - output_accuracy: 0.5304 - auxilliary_output_1_accuracy: 0.5216 - auxilliary_output_2_accuracy: 0.5267 - val_loss: 5.9653 - val_output_loss: 4.3062 - val_auxilliary_output_1_loss: 2.3625 - val_auxilliary_output_2_loss: 3.2408 - val_output_accuracy: 0.1000 - val_auxilliary_output_1_accuracy: 0.1122 - val_auxilliary_output_2_accuracy: 0.1154
# Epoch 6/25
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.01.
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.9681 - output_loss: 1.2180 - auxilliary_output_1_loss: 1.2606 - auxilliary_output_2_loss: 1.2391 - output_accuracy: 0.5649 - auxilliary_output_1_accuracy: 0.5545 - auxilliary_output_2_accuracy: 0.5624 - val_loss: 5.9864 - val_output_loss: 4.2950 - val_auxilliary_output_1_loss: 2.3545 - val_auxilliary_output_2_loss: 3.3489 - val_output_accuracy: 0.1209 - val_auxilliary_output_1_accuracy: 0.1592 - val_auxilliary_output_2_accuracy: 0.1556
# Epoch 7/25
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.01.
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.8756 - output_loss: 1.1610 - auxilliary_output_1_loss: 1.1984 - auxilliary_output_2_loss: 1.1820 - output_accuracy: 0.5891 - auxilliary_output_1_accuracy: 0.5811 - auxilliary_output_2_accuracy: 0.5848 - val_loss: 5.9126 - val_output_loss: 4.2161 - val_auxilliary_output_1_loss: 2.3289 - val_auxilliary_output_2_loss: 3.4017 - val_output_accuracy: 0.1568 - val_auxilliary_output_1_accuracy: 0.1499 - val_auxilliary_output_2_accuracy: 0.1612
# Epoch 8/25
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0096.
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.7409 - output_loss: 1.0755 - auxilliary_output_1_loss: 1.1165 - auxilliary_output_2_loss: 1.1003 - output_accuracy: 0.6180 - auxilliary_output_1_accuracy: 0.6122 - auxilliary_output_2_accuracy: 0.6159 - val_loss: 5.9769 - val_output_loss: 4.2706 - val_auxilliary_output_1_loss: 2.3325 - val_auxilliary_output_2_loss: 3.4307 - val_output_accuracy: 0.1359 - val_auxilliary_output_1_accuracy: 0.1142 - val_auxilliary_output_2_accuracy: 0.1234
# Epoch 9/25
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0096.
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.6271 - output_loss: 1.0043 - auxilliary_output_1_loss: 1.0466 - auxilliary_output_2_loss: 1.0244 - output_accuracy: 0.6458 - auxilliary_output_1_accuracy: 0.6361 - auxilliary_output_2_accuracy: 0.6430 - val_loss: 6.0152 - val_output_loss: 4.2798 - val_auxilliary_output_1_loss: 2.3340 - val_auxilliary_output_2_loss: 3.5225 - val_output_accuracy: 0.1571 - val_auxilliary_output_1_accuracy: 0.1591 - val_auxilliary_output_2_accuracy: 0.1639
# Epoch 10/25
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0096.
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.5361 - output_loss: 0.9494 - auxilliary_output_1_loss: 0.9878 - auxilliary_output_2_loss: 0.9667 - output_accuracy: 0.6639 - auxilliary_output_1_accuracy: 0.6591 - auxilliary_output_2_accuracy: 0.6638 - val_loss: 6.0784 - val_output_loss: 4.3412 - val_auxilliary_output_1_loss: 2.3330 - val_auxilliary_output_2_loss: 3.5334 - val_output_accuracy: 0.1601 - val_auxilliary_output_1_accuracy: 0.1335 - val_auxilliary_output_2_accuracy: 0.1628
# Epoch 11/25
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0096.
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.4557 - output_loss: 0.8983 - auxilliary_output_1_loss: 0.9378 - auxilliary_output_2_loss: 0.9178 - output_accuracy: 0.6858 - auxilliary_output_1_accuracy: 0.6760 - auxilliary_output_2_accuracy: 0.6850 - val_loss: 6.2305 - val_output_loss: 4.4685 - val_auxilliary_output_1_loss: 2.3311 - val_auxilliary_output_2_loss: 3.6186 - val_output_accuracy: 0.1549 - val_auxilliary_output_1_accuracy: 0.1690 - val_auxilliary_output_2_accuracy: 0.1680
# Epoch 12/25
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0096.
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.3933 - output_loss: 0.8601 - auxilliary_output_1_loss: 0.9014 - auxilliary_output_2_loss: 0.8784 - output_accuracy: 0.6999 - auxilliary_output_1_accuracy: 0.6895 - auxilliary_output_2_accuracy: 0.6975 - val_loss: 6.1402 - val_output_loss: 4.3913 - val_auxilliary_output_1_loss: 2.3316 - val_auxilliary_output_2_loss: 3.5710 - val_output_accuracy: 0.1643 - val_auxilliary_output_1_accuracy: 0.1673 - val_auxilliary_output_2_accuracy: 0.1720
# Epoch 13/25
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0096.
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.3208 - output_loss: 0.8133 - auxilliary_output_1_loss: 0.8582 - auxilliary_output_2_loss: 0.8303 - output_accuracy: 0.7149 - auxilliary_output_1_accuracy: 0.7024 - auxilliary_output_2_accuracy: 0.7138 - val_loss: 6.3432 - val_output_loss: 4.5602 - val_auxilliary_output_1_loss: 2.3404 - val_auxilliary_output_2_loss: 3.6791 - val_output_accuracy: 0.1709 - val_auxilliary_output_1_accuracy: 0.1235 - val_auxilliary_output_2_accuracy: 0.1559
# Epoch 14/25
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0096.
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.2441 - output_loss: 0.7666 - auxilliary_output_1_loss: 0.8105 - auxilliary_output_2_loss: 0.7826 - output_accuracy: 0.7324 - auxilliary_output_1_accuracy: 0.7225 - auxilliary_output_2_accuracy: 0.7308 - val_loss: 6.2497 - val_output_loss: 4.5021 - val_auxilliary_output_1_loss: 2.3133 - val_auxilliary_output_2_loss: 3.5932 - val_output_accuracy: 0.1356 - val_auxilliary_output_1_accuracy: 0.1704 - val_auxilliary_output_2_accuracy: 0.1643
# Epoch 15/25
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0096.
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1627 - output_loss: 0.7158 - auxilliary_output_1_loss: 0.7596 - auxilliary_output_2_loss: 0.7310 - output_accuracy: 0.7502 - auxilliary_output_1_accuracy: 0.7405 - auxilliary_output_2_accuracy: 0.7484 - val_loss: 6.3569 - val_output_loss: 4.5617 - val_auxilliary_output_1_loss: 2.3250 - val_auxilliary_output_2_loss: 3.7422 - val_output_accuracy: 0.1680 - val_auxilliary_output_1_accuracy: 0.1486 - val_auxilliary_output_2_accuracy: 0.1649
# Epoch 16/25
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.009216.
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1157 - output_loss: 0.6858 - auxilliary_output_1_loss: 0.7313 - auxilliary_output_2_loss: 0.7029 - output_accuracy: 0.7617 - auxilliary_output_1_accuracy: 0.7500 - auxilliary_output_2_accuracy: 0.7607 - val_loss: 6.0954 - val_output_loss: 4.3770 - val_auxilliary_output_1_loss: 2.2899 - val_auxilliary_output_2_loss: 3.5156 - val_output_accuracy: 0.1604 - val_auxilliary_output_1_accuracy: 0.1549 - val_auxilliary_output_2_accuracy: 0.1626
# Epoch 17/25
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.009216.
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0200 - output_loss: 0.6257 - auxilliary_output_1_loss: 0.6720 - auxilliary_output_2_loss: 0.6409 - output_accuracy: 0.7816 - auxilliary_output_1_accuracy: 0.7717 - auxilliary_output_2_accuracy: 0.7801 - val_loss: 6.5383 - val_output_loss: 4.7242 - val_auxilliary_output_1_loss: 2.3216 - val_auxilliary_output_2_loss: 3.8084 - val_output_accuracy: 0.1303 - val_auxilliary_output_1_accuracy: 0.1721 - val_auxilliary_output_2_accuracy: 0.1628
# Epoch 18/25
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.009216.
# 50000/50000 [==============================] - 11s 220us/step - loss: 0.9807 - output_loss: 0.6020 - auxilliary_output_1_loss: 0.6445 - auxilliary_output_2_loss: 0.6176 - output_accuracy: 0.7916 - auxilliary_output_1_accuracy: 0.7809 - auxilliary_output_2_accuracy: 0.7881 - val_loss: 6.1902 - val_output_loss: 4.4461 - val_auxilliary_output_1_loss: 2.2933 - val_auxilliary_output_2_loss: 3.5950 - val_output_accuracy: 0.1743 - val_auxilliary_output_1_accuracy: 0.1741 - val_auxilliary_output_2_accuracy: 0.1676
# Epoch 19/25
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.009216.
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.8761 - output_loss: 0.5360 - auxilliary_output_1_loss: 0.5846 - auxilliary_output_2_loss: 0.5498 - output_accuracy: 0.8116 - auxilliary_output_1_accuracy: 0.8004 - auxilliary_output_2_accuracy: 0.8103 - val_loss: 6.3152 - val_output_loss: 4.5452 - val_auxilliary_output_1_loss: 2.3069 - val_auxilliary_output_2_loss: 3.6686 - val_output_accuracy: 0.1696 - val_auxilliary_output_1_accuracy: 0.1718 - val_auxilliary_output_2_accuracy: 0.1749
# Epoch 20/25
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.009216.
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.8400 - output_loss: 0.5135 - auxilliary_output_1_loss: 0.5592 - auxilliary_output_2_loss: 0.5252 - output_accuracy: 0.8181 - auxilliary_output_1_accuracy: 0.8079 - auxilliary_output_2_accuracy: 0.8167 - val_loss: 6.5978 - val_output_loss: 4.8030 - val_auxilliary_output_1_loss: 2.2956 - val_auxilliary_output_2_loss: 3.7691 - val_output_accuracy: 0.1747 - val_auxilliary_output_1_accuracy: 0.1755 - val_auxilliary_output_2_accuracy: 0.1738
# Epoch 21/25
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.009216.
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.7984 - output_loss: 0.4877 - auxilliary_output_1_loss: 0.5347 - auxilliary_output_2_loss: 0.5021 - output_accuracy: 0.8307 - auxilliary_output_1_accuracy: 0.8184 - auxilliary_output_2_accuracy: 0.8297 - val_loss: 6.6219 - val_output_loss: 4.8420 - val_auxilliary_output_1_loss: 2.2985 - val_auxilliary_output_2_loss: 3.7173 - val_output_accuracy: 0.1709 - val_auxilliary_output_1_accuracy: 0.1738 - val_auxilliary_output_2_accuracy: 0.1750
# Epoch 22/25
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.009216.
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.7492 - output_loss: 0.4573 - auxilliary_output_1_loss: 0.5047 - auxilliary_output_2_loss: 0.4706 - output_accuracy: 0.8399 - auxilliary_output_1_accuracy: 0.8266 - auxilliary_output_2_accuracy: 0.8399 - val_loss: 6.3651 - val_output_loss: 4.6069 - val_auxilliary_output_1_loss: 2.2869 - val_auxilliary_output_2_loss: 3.6464 - val_output_accuracy: 0.1765 - val_auxilliary_output_1_accuracy: 0.1758 - val_auxilliary_output_2_accuracy: 0.1767
# Epoch 23/25
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.009216.
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.7053 - output_loss: 0.4301 - auxilliary_output_1_loss: 0.4767 - auxilliary_output_2_loss: 0.4428 - output_accuracy: 0.8529 - auxilliary_output_1_accuracy: 0.8384 - auxilliary_output_2_accuracy: 0.8501 - val_loss: 6.2954 - val_output_loss: 4.5585 - val_auxilliary_output_1_loss: 2.2863 - val_auxilliary_output_2_loss: 3.5816 - val_output_accuracy: 0.1728 - val_auxilliary_output_1_accuracy: 0.1775 - val_auxilliary_output_2_accuracy: 0.1745
# Epoch 24/25
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.6321 - output_loss: 0.3844 - auxilliary_output_1_loss: 0.4328 - auxilliary_output_2_loss: 0.3958 - output_accuracy: 0.8663 - auxilliary_output_1_accuracy: 0.8536 - auxilliary_output_2_accuracy: 0.8653 - val_loss: 6.4081 - val_output_loss: 4.7110 - val_auxilliary_output_1_loss: 2.2556 - val_auxilliary_output_2_loss: 3.4803 - val_output_accuracy: 0.1782 - val_auxilliary_output_1_accuracy: 0.1792 - val_auxilliary_output_2_accuracy: 0.1721
# Epoch 25/25
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.6109 - output_loss: 0.3702 - auxilliary_output_1_loss: 0.4160 - auxilliary_output_2_loss: 0.3846 - output_accuracy: 0.8705 - auxilliary_output_1_accuracy: 0.8581 - auxilliary_output_2_accuracy: 0.8685 - val_loss: 6.3911 - val_output_loss: 4.6690 - val_auxilliary_output_1_loss: 2.2716 - val_auxilliary_output_2_loss: 3.5553 - val_output_accuracy: 0.1781 - val_auxilliary_output_1_accuracy: 0.1756 - val_auxilliary_output_2_accuracy: 0.1777
